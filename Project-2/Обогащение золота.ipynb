# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Николай, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Исследуем-исходный-Дата-Фрейм" data-toc-modified-id="Исследуем-исходный-Дата-Фрейм-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Исследуем исходный Дата Фрейм</a></span></li><li><span><a href="#Исследуем-обучающую-выборку" data-toc-modified-id="Исследуем-обучающую-выборку-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Исследуем обучающую выборку</a></span></li><li><span><a href="#Исследуем-тестовую-выборку" data-toc-modified-id="Исследуем-тестовую-выборку-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследуем тестовую выборку</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Рассмотрим-этап-флотации" data-toc-modified-id="Рассмотрим-этап-флотации-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Рассмотрим этап флотации</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-этапу-флотации" data-toc-modified-id="Выводы-по-этапу-флотации-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Выводы по этапу флотации</a></span></li></ul></li><li><span><a href="#Рассмотрим-этап-первичной-очистки" data-toc-modified-id="Рассмотрим-этап-первичной-очистки-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Рассмотрим этап первичной очистки</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-результатам-первичной-очистки" data-toc-modified-id="Выводы-по-результатам-первичной-очистки-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Выводы по результатам первичной очистки</a></span></li></ul></li><li><span><a href="#Рассмотрим-этап-вторичной-очистки" data-toc-modified-id="Рассмотрим-этап-вторичной-очистки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Рассмотрим этап вторичной очистки</a></span><ul class="toc-item"><li><span><a href="#Выводы-по-этапу-вторичной-очистки" data-toc-modified-id="Выводы-по-этапу-вторичной-очистки-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Выводы по этапу вторичной очистки</a></span></li></ul></li><li><span><a href="#Завершающий-этап-на-котором-получаем---Финальные-характеристики,-сравнение-средних-и-распределений" data-toc-modified-id="Завершающий-этап-на-котором-получаем---Финальные-характеристики,-сравнение-средних-и-распределений-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Завершающий этап на котором получаем - Финальные характеристики, сравнение средних и распределений</a></span></li><li><span><a href="#Выводы-по-результатам-анализа-данных" data-toc-modified-id="Выводы-по-результатам-анализа-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы по результатам анализа данных</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Построим-модель-Линейной-Регрессии" data-toc-modified-id="Построим-модель-Линейной-Регрессии-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Построим модель Линейной Регрессии</a></span></li><li><span><a href="#Обучим-модель-DecisionTreeRegressor" data-toc-modified-id="Обучим-модель-DecisionTreeRegressor-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучим модель DecisionTreeRegressor</a></span></li><li><span><a href="#Обучим-модель-Случайного-леса" data-toc-modified-id="Обучим-модель-Случайного-леса-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучим модель Случайного леса</a></span></li><li><span><a href="#Проверка-на-тестовой-выборке" data-toc-modified-id="Проверка-на-тестовой-выборке-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка на тестовой выборке</a></span></li><li><span><a href="#Выводы-по-результатам-метрик-моделей" data-toc-modified-id="Выводы-по-результатам-метрик-моделей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы по результатам метрик моделей</a></span></li><li><span><a href="#Итоговый-вывод" data-toc-modified-id="Итоговый-вывод-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Итоговый вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Прекрасное вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!
#
# Спасибо, что есть оглавление в плагине toc и в виде гиперссылок - по проекту удобно перемещаться:)

# %% [markdown]
# ## Подготовка данных

# %%
#импортируем необходимые библиотеки
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.dummy import DummyRegressor

from tqdm import tqdm
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
rand = RANDOM_STATE = 12345
from sklearn.preprocessing import StandardScaler 
from scipy import stats as st
import warnings
warnings.filterwarnings('ignore')
from sklearn import svm
from sklearn.model_selection import cross_validate

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично! Спасибо, что перезапускаешь проект перед отправкой на ревью - это важный шаг, который поможет избежать простых и досадных ошибок при воспроизведении решнеия:)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Ты импортируешь библиотеки и модули, которые не используешь в проекте - так делать не стоит, так как ты забиваешь окружение лишними  инструментами.
#
# В блоке импорта стоит оставить только то, что реально используется в проекте.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Удалил, которые стали не нужны.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Всё ещё очень много ненужных модулей не удалено из импорта - можешь через `Ctrl+F` пройтись по ним и проверить, что используется, а что - нет.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Удалил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [raw]
# # Загрузим Дата Фрейм
# try:
#     df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
#     df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
#     df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')
#     print('Загружено успешно')
# except:
#     print('Ошибка загрузки, измените путь')

# %%
import os

pth1_train = '/datasets/gold_recovery_train_new.csv'
pth1_test = '/datasets/gold_recovery_test_new.csv'
pth1_full = '/datasets/gold_recovery_full_new.csv'

pth2_train = 'gold_recovery_train_new.csv'
pth2_test = 'gold_recovery_test_new.csv'
pth2_full = 'gold_recovery_full_new.csv'


if os.path.exists(pth1_train):
    df_train = pd.read_csv(pth1_train)
    df_test = pd.read_csv(pth1_test)
    df_full = pd.read_csv(pth1_full)
elif os.path.exists(pth2_train):
    df_train = pd.read_csv(pth2_train)
    df_test = pd.read_csv(pth2_test)
    df_full = pd.read_csv(pth2_full)
else:
    print('Something is wrong')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Данные загрузили - отлично!
#
# Здорово, что ты используешь конструкцию ``try-except`` для путей файлов. Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Попробовал аналогичный метод. Спасибо.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Пожалуйста:)

# %%
# Сброс ограничений на количество выводимых рядов
pd.set_option('display.max_rows', None)
 
# Сброс ограничений на число столбцов
pd.set_option('display.max_columns', None)
 
# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Исследуем исходный Дата Фрейм

# %%
# Посмотрим общую информацию о Дата фрейме
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
# Возьмем случайную выборку данных и посмотрим на них
df_full.sample(5)
# Out:
#                       date  final.output.concentrate_ag  \
# 6850   2016-12-12 09:59:59                     6.703612
# 1070   2016-03-03 09:00:00                     4.641952
# 14182  2017-11-22 14:59:59                     4.945336
# 10534  2017-06-11 06:59:59                     4.390029
# 14799  2017-12-19 18:59:59                     6.138837
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 6850                      9.755883                     11.193473
# 1070                     10.611605                      5.323000
# 14182                    10.439262                      8.740098
# 10534                    10.212738                      9.750749
# 14799                     9.534836                     11.439277
#
#        final.output.concentrate_au  final.output.recovery  \
# 6850                     42.307529              74.294426
# 1070                     44.407647              61.096236
# ...

# %%
# Посмотрим на пустые строки в столбцах
df_full.isnull().sum()
# Out:
# date                                                     0
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.concentrate_au                              0
# final.output.recovery                                    0
# final.output.tail_ag                                     1
# final.output.tail_pb                                   101
# final.output.tail_sol                                    6
# final.output.tail_au                                     0
# primary_cleaner.input.sulfate                           24
# primary_cleaner.input.depressant                        37
# primary_cleaner.input.feed_size                          0
# primary_cleaner.input.xanthate                         104
# primary_cleaner.output.concentrate_ag                    0
# primary_cleaner.output.concentrate_pb                  116
# ...

# %%
# Выделяем пустые ячейки
pd.DataFrame(round(df_full.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# В тренеровочной выборке видно 11 столбцов с пропусками, столбец secondary_cleaner.output.tail_sol содержит более 9% пропусков. Остальные пустые строки можно заменить на пердыдущие значения. Т.к. это конвеер.

# %%
# Полные дубликаты строк
df_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Исследуем обучающую выборку

# %%
# Посмотрим общую информацию о Дата фрейме
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
# Возьмем случайную выборку данных и посмотрим на них
df_train.sample(5)
# Out:
#                       date  final.output.concentrate_ag  \
# 12061  2018-05-05 21:59:59                     5.464801
# 7589   2017-05-25 04:59:59                     5.898572
# 3260   2016-06-25 10:59:59                     6.802889
# 2820   2016-06-06 08:59:59                     3.939412
# 7033   2017-04-22 22:59:59                     5.592845
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 12061                    10.782459                      7.435599
# 7589                     11.173924                     10.825441
# 3260                      9.275762                     10.239303
# 2820                      9.028539                      7.933384
# 7033                     11.087529                      9.316539
#
#        final.output.concentrate_au  final.output.recovery  \
# 12061                    42.356312              71.737313
# 7589                     42.494898              62.460435
# ...

# %%
df_train.isnull().sum()
# Out:
# date                                                     0
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.concentrate_au                              0
# final.output.recovery                                    0
# final.output.tail_ag                                     0
# final.output.tail_pb                                   100
# final.output.tail_sol                                    5
# final.output.tail_au                                     0
# primary_cleaner.input.sulfate                           20
# primary_cleaner.input.depressant                        32
# primary_cleaner.input.feed_size                          0
# primary_cleaner.input.xanthate                         100
# primary_cleaner.output.concentrate_ag                    0
# primary_cleaner.output.concentrate_pb                   86
# ...

# %%
# Выделяем пустые ячейки
pd.DataFrame(round(df_train.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# В тренеровочной выборке видно 11 столбцов с пропусками, столбец secondary_cleaner.output.tail_sol содержит более 11% пропусков. Остальные пустые строки можно безболезнено удалить, <b>однако т.к. это конвеер заменим на предыдущие значения. В полне возможно, что за один час состав руды изменился не значительно, а руда скорее всего будет из одного места. Так, что удаление отложим на крайний случай и воспользуемся стратегией заполнения ffill.</b>

# %%
# Напишим цикл и заменим пропуски на значения которые были до этого.
# ДатаФрейм идет попрядку, сортировка не требуется
for x in df_train.columns:
    try:
        if df_train[x].isna().sum() > 0:
            df_train[x] = df_train[x].fillna(method='ffill')
    except:
        print('Error')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обработали пропуски с помощью стратегии заполнения `backward fill` - отлично!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# 1. Комментарий с обоснованием стратегии работы с пропусками стоит оформить как Markdown-ячейку.
# 2. Метод `bfill()` заполняет пропуски следующим значением, а не предыдущим - для предыдущего есть `ffill()`. Скорректируй, пожалуйста, своё описание.
# 3. Также ты пишешь в комментарии, что в столбцах с невысоким количеством пропусков их можно удалить, хотя ничего не удаляешь - этот момент тоже нужно синхроинзировать.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил. Ffill тоже испоьзовал, забыл исправить.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Выделяем пустые ячейки
pd.DataFrame(round(df_train.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
# Уберем аномалии
df_train["rougher.input.feed"] = df_train["rougher.input.feed_au"] + df_train["rougher.input.feed_ag"] + df_train["rougher.input.feed_pb"] + df_train["rougher.input.feed_sol"] 
df_train["rougher.output.concentrate"] = df_train["rougher.output.concentrate_au"] + df_train["rougher.output.concentrate_ag"] + df_train["rougher.output.concentrate_pb"] + df_train["rougher.output.concentrate_sol"]
df_train["final.output.concentrate"] = df_train["final.output.concentrate_au"] + df_train["final.output.concentrate_ag"] + df_train["final.output.concentrate_pb"] + df_train["final.output.concentrate_sol"]
df_train = df_train[(df_train["rougher.input.feed"] > 20) & (df_train["rougher.output.concentrate"] > 20) & (df_train["final.output.concentrate"] > 20)]
df_train = df_train.drop(["rougher.input.feed", "rougher.output.concentrate", "final.output.concentrate"], axis=1)

# %%
# Найдем столбцы которых нет в тестовой выборке
no_in_test = list(filter(lambda x: x not in df_test.columns, df_full.columns))

# %%
no_in_test
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Нашли разницу в признаках между выборками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Список отсутствующих признаков стоит вывести на экран.
#
# Также исходя из понимания, что тестовая выборка имитирует работу модели в реальных условиях протекания технологического процесса, давай подумаем, почему в `train` есть признаки, которые недоступны в `test`?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил. Возможно, это дополнительная подсказка какие столбцы нужны для обучения модели. А еще момент, что данные output появляются после завершения процесса флотации/очистки. Calculations могут являться каналом утечки данных из целевой переменной в признаки. Также преподаватель, советовал нам разделить модели на этапы, чтобы не было утечки данных.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В целом верно: в тестовой выборке присутствуют только те параметры техпроцесса, которые мы можем получить непосредственно в ходе процесса или по его окончании.

# %%
df_train_good = df_train.drop(columns=no_in_test)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Синхронизировали тренировочную и тестовую выборки по набору признаков - хорошо!
# </div>

# %%
df_train_good.isna().sum()
# Out:
# date                                          0
# primary_cleaner.input.sulfate                 0
# primary_cleaner.input.depressant              0
# primary_cleaner.input.feed_size               0
# primary_cleaner.input.xanthate                0
# primary_cleaner.state.floatbank8_a_air        0
# primary_cleaner.state.floatbank8_a_level      0
# primary_cleaner.state.floatbank8_b_air        0
# primary_cleaner.state.floatbank8_b_level      0
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_air        0
# primary_cleaner.state.floatbank8_d_level      0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_rate                       0
# rougher.input.feed_size                       0
# rougher.input.feed_sol                        0
# rougher.input.feed_au                         0
# rougher.input.floatbank10_sulfate             0
# ...

# %%
# Функция расчета эффективости обогащения
def recovery(c, f, t):
    recover = ((c*(f-t))/(f*(c-t)))*100
    return recover

# %%
# применим функция расчета обгащения
df_train['recovery_new'] = df_train.apply(lambda x: recovery(x['rougher.output.concentrate_au'], x['rougher.input.feed_au'], x['rougher.output.tail_au']), axis=1)

# %%
# Введем новые переменные
recovery_train = df_train['rougher.output.recovery']
recovery_new = df_train['recovery_new']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Если идём по пути сравнения выборок через А/В тест, то нужно сформулировать гипоетзы - нулевую или альтернативную.
#
# Кроме того, не хватает обоснования использования `ttest` в качестве критерия их проверки - можем ли мы вообще его применять, или нам нужно что-то непараметрическое?
#
#
# Также не очень понятно, почему тест односторонний, потому что ты не ищешь преобладание какой-то группы над одной, а просто разницу между ними - в таком случае односторонний тест делать не нужно. Ну и в целом на односторонний тест корректируется не `p-value`, а уровень значимости. Так как выборки идентичны, то мы ожидаемо должны были получить единичное `p-value`, а значение в `0.5` говорит, что различия всё же есть, что противоречит результатам `MAE` ниже.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Нам важно понять выборки одиныковые или различаются. Мне кажется изменения среднего значения это лучшего всего показывает.
#     <p>Мне казалось, что у меня двусторонний тест. Если деление на 2 убрать, то получится 1, а на самом деле наооборот. В теории мы использовали подобный тест и нам там важно было увеличение прибыли, потому тест был односторонний.
# <p>Если я мыслю не в правильном направлении, то я могу убрать тест, но почему то мне кажется, что тест тоже хорошо показывает, что распределения одинаковые, т.к. средние не изменились. Двусторонний тест лучше, т.к. он показывает изменения  в двух направлениях (по теории).
#     <p>H0 Среднее значение выборки 1 = Среднему значению выборки 2
#     <p>H1 Среднее значение выборки 1 /= Среднему значению выборки 2
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Тут нет вопросов к тесту как к инструменту сравнения выборок, нпротив - это очень классный подход. Замечания призваны его отшлифовать. Давай по порядку:
# 1. Так в том и дело, что и здесь у нас гипотеза про то, что средние не равны или равны, а не про то, что какое-то среднее больше/меньше другого. Поэтому тест нужен двусторонний, а не односторонний. Когда ты делил `p_value` на два, ты делал односторонний тест, сейчас без деления он двусторонний - это корректно.
# 2. По гипотезам - всё ок.
# 3. Но использование `ttest` ты так и не обосновал - подскажу, что его обоснование может быть связано с количеством наблюдений в выборке: при достаточном количестве (хотя бы более 50) наблюдений мы можем применять `ttest` к выборкам, которые не распределены нормально. Это нужно отразить в выводе.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2 <a class="tocSkip"> </h2>
# <p> Распределения имеют смещение влево. Колличество наблюдений в выборках одинаково и достаточно для проведения сплит теста.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Проведем A/B тест и сравним как изменились средние значения
# критический уровень статистической значимости

alpha = .01 
results = st.ttest_ind(recovery_train, recovery_new) 

# тест односторонний: p-value будет в два раза меньше
pvalue = results.pvalue 

print('p-значение: ', pvalue)

if pvalue < alpha:
    print("Отвергаем нулевую гипотезу: скорее всего среднее значение изменилось")
else:
    print("Не получилось отвергнуть нулевую гипотезу: скорее всего среднее значение не изменилось")
# Out:
# p-значение:  1.0
# Не получилось отвергнуть нулевую гипотезу: скорее всего среднее значение не изменилось

# %%
print("Посмотрим метрику для MAE - среднего абсолютного отклонения", mean_absolute_error(recovery_train, recovery_new))
# Out:
# Посмотрим метрику для MAE - среднего абсолютного отклонения 9.951786784856275e-15

# %% [markdown]
# Метрика близка к нулю, говорит почти о стопроцентной схожести. Разница может быть вызвана особенностями расчетов вещественных чисел.
# <b>A/B тест и метрика MAE показывает, что значения почти идентичны.</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили `MAE` между исходным и расчётным значением эффективности обогащения и убедились, что эффективность обогащения рассчитана правильно - отлично!
# </div>

# %%
# Полные дубликаты строк
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Исследуем тестовую выборку

# %%
# Посмотрим общую информацию о Дата фрейме
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
# Возьмем случайную выборку данных и посмотрим на них
df_test.head(5)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
# Посмотрим на пустые строки в столбцах
df_test.isnull().sum()
# Out:
# date                                           0
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# ...

# %%
# Выделяем пустые ячейки
pd.DataFrame(round(df_test.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_b1d81_row0_col0,#T_b1d81_row3_col0,#T_b1d81_row5_col0,#T_b1d81_row6_col0,#T_b1d81_row7_col0,#T_b1d81_row8_col0,#T_b1d81_row9_col0,#T_b1d81_row10_col0,#T_b1d81_row11_col0,#T_b1d81_row12_col0,#T_b1d81_row13_col0,#T_b1d81_row14_col0,#T_b1d81_row16_col0,#T_b1d81_row18_col0,#T_b1d81_row20_col0,#T_b1d81_row23_col0,#T_b1d81_row24_col0,#T_b1d81_row25_col0,#T_b1d81_row26_col0,#T_b1d81_row27_col0,#T_b1d81_row28_col0,#T_b1d81_row29_col0,#T_b1d81_row30_col0,#T_b1d81_row31_col0,#T_b1d81_row32_col0,#T_b1d81_row33_col0,#T_b1d81_row34_col0,#T_b1d81_row36_col0,#T_b1d81_row37_col0,#T_b1d81_row38_col0,#T_b1d81_row40_col0,#T_b1d81_row41_col0,#T_b1d81_row42_col0,#T_b1d81_row43_col0,#T_b1d81_row44_col0,#T_b1d81_row45_col0,#T_b1d81_row46_col0,#T_b1d81_row47_col0,#T_b1d81_row48_col0,#T_b1d81_row49_col0,#T_b1d81_row50_col0,#T_b1d81_row51_col0,#T_b1d81_row52_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# В тестовой выборке есть пустые строки, но их количество минимально. т.к. это конвеер заменим на предыдущие значения. В полне возможно, что за один час состав руды изменился не значительно, а руда скорее всего будет из одного места. Так, что удаление отложим на крайний случай и воспользуемся стратегией заполнения ffill.</b>

# %%
# Учитывая, что это конвеер и данные собираются еже часно,
# а места добычи руда врядли меняются каждый час. Напишим цикл и заменим пропуски на значения которые были до этого.
# ДатаФрейм идет попрядку, сортировка не требуется
for x in df_test.columns:
    try:
        if df_test[x].isna().sum() > 0:
            df_test[x] = df_test[x].fillna(method='ffill')
    except:
        print('Error')

# %%
df_test.shape
# Out:
# (5290, 53)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# А что мы тут могли потерять, если ничего не удаляли?

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил. Осталось лишнее после первого варианта, я там восстанавливал только важные признаки (которые используются в обучении) из коррелирующих признаков.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, понял.

# %%
# Выделяем пустые ячейки
pd.DataFrame(round(df_test.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
# Полные дубликаты строк
df_test.duplicated().sum()
# Out:
# 0

# %%
# Посмотрим как столбцов нет в тестовой выборке
no_in_test
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# <b>Такой оъбем информации для неподготовленного сознания представляет собой проблему, поэтому применим метод декомпозиции и постораемся ее решить. Для начала разделим полный ДатаФрейм на этапы очистки дробленой смеси золотоносной руды или иныче декомпозируем на процессы часть бизнес процесса по производству золота (производственный процесс от дробленной смеси до финального концентрата), имеющегося у нас в распоряжении.</b>

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Рассмотрим этап флотации

# %%
# Выделим в отдельный датафрейм данные Первого этапа 
rougher_df = df_full[[x for x in df_full.columns if 'rougher' in x]]

# %%
# Посмотрим на описание ДФ
rougher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 35 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  1   rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  2   rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  3   rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  4   rougher.input.feed_ag                               19439 non-null  float64
#  5   rougher.input.feed_pb                               19339 non-null  float64
#  6   rougher.input.feed_rate                             19428 non-null  float64
#  7   rougher.input.feed_size                             19294 non-null  float64
# ...

# %%
rougher_df.head()
# Out:
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                         3481.779053
# 1                                         3498.370979
# 2                                         3495.348910
# 3                                         3498.578313
# 4                                         3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                         3520.337158
# 1                                         3489.981857
# 2                                         3502.359819
# 3                                         3499.162912
# 4                                         3506.679315
#
# ...

# %%
# Добавляем наглядности к корреляции
corrmat = rougher_df.corr()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corrmat,  square=True);
plt.xlabel("Признаки")
plt.ylabel("Признаки")
plt.title("Тепловая карта корреляции признаков") ;

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# На матрице корреляций нужно подписать название.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <p>Из данного датафрейма видно, что на этапе флотации происходит расчет количества реагентов, на основе параметров исходного сырья, далее подача сырья флотационную установку. В данной установке происходит дважды добавление реагентов и многоступенчатое изменение объема воздуха и уровня жидкости. В итоге на выходе появляются концентраты ag, pb, sol, au и такие же анлогичные хвосты.</p>
# <p>Из преведенной выше тепловой карты видна слабая линейна взаимозависимость между параметрами скорости подачи сырья и добавлением концентратов, а также слабые линенейные зависимости на входе в содержании металлов в сырье и на выходы концентратов металлов между сабой после очистки.</p>
# <p>Также видна зависимость средняя обратная зависимость между параметром rougher.calculation.au_pb_ratio и параметром сырья содержащего свинец. И есть линейные зависимости выше средней между параметраме входной продукции серебра и свинца, золота и свинца.</p>
# <p>И более чем логично, показатель rougher.output.recovery имеет выше средней корреляцию (линейную зависимость) с выходом параметров концентрата металлов.</p>
# <p>Также видно, что между параметрами уровня воды и жидкости присутствует высокая линейная зависимость.</p>
# <p>Кроме того, присутствует масса иных зависимостей линейных и обратных между параметрами, которые решил не описывать.</p>

# %% [markdown]
# <b>Посмотрим на распределение значений через диаграмму BOX PLOT</b>

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.calculation.floatbank10_sulfate_to_au_feed',\
                            'rougher.calculation.floatbank11_sulfate_to_au_feed'], figsize=(15,5) , vert=False);
plt.ylabel('Распределение расчетных характеристик ')
plt.xlim(-1000, 30000)
plt.show
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT расчетных признаков") ;

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Тут и далее на графиках должны быть подписаны названия и оси Х/Y. Вместо дефолтных подписей стоит добавить более информативные.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Добавил название диаграмм и описание осей.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# По оси Y тут не дисперсия, а просто значение признака - тут и далее по всем графикам этого блока, видимо, просто копипаста пошла:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Видно я, что-то напутал. Мне казалось что все значения выборки и есть дисперсия.
# Заменил. Основные графики я описал полностью.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Видны явные выбросы, очень похожие на аномальные значения. Распределение значений смещено вправо.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.calculation.sulfate_to_au_concentrate'],figsize=(6,3), vert=False);
plt.xlim(0, 70000)
plt.xlabel("Значения")
plt.ylabel("Название признака")
plt.title("Диаграмма BOX-PLOT расчетного признака") ;
plt.show;

# %% [markdown]
# Видны явные выбросы, очень похожие на аномальные значения. Распределение значений напоминает распределение Пауссона.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot(column=['rougher.calculation.au_pb_ratio'],figsize=(6,3), vert=False);
plt.ylabel('Распределение расчетных характеристик ')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT расчетных характеристик") ;
plt.show;

# %%
# Построим гистограмму
rougher_df.hist(column=['rougher.calculation.au_pb_ratio'], figsize=(15,5), bins=100)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.suptitle("Диаграмма распределения расчетных характеристик");

# %% [markdown]
# В расчетных характеристиках, видны выбросы, очень похожие на ономальные значения. Распределение смещено вправо.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.input.feed_ag', 'rougher.input.feed_pb', \
                           'rougher.input.feed_sol', 'rougher.input.feed_au'],figsize=(20,8), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT распредлений концентрации минералов в сырье") ;
plt.show;

# %%
# Построим гистограмму
rougher_df.hist(column=['rougher.input.feed_ag', 'rougher.input.feed_pb', \
                           'rougher.input.feed_sol', 'rougher.input.feed_au'], figsize=(15,5), bins=50)

plt.suptitle("Гистограммы распределения значений концентрации минералов в сырье");

# %% [markdown]
# В расчетных характеристиках, видны выбросы, очень похожие на ономальные значения (особенно в Feed_sol). Все распределения имеют минимум по два горба (моды). В этих признаках была перекрестная корреляция. Возможно содержание одного влияет на содержание другого, либо данные моды также могут отражать содержание металлов в руде. Руда из разных мест имеет разные концентрации. Также можно отметить, что содержание входного сырья Feed_sol многократно превышает значения других металлов.
# Содержание металлов:
# - серебро от 4 до 14
# - свинец от 1 до 7
# - золото от 4 до 13
# - sol от 20 до 45

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.input.feed_rate'],figsize=(6,3), vert=False);
plt.ylabel('Скорость подачи - Флотация ')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT") ;
plt.show;

# %%
# Построим гистограмму
rougher_df.hist(column=['rougher.input.feed_rate'], figsize=(15,5), bins=100)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Распределение значений расчета калькуляции добавления сульфата");

# %% [markdown]
# Не совсем понятно как собирается данный признак. Предположим, что это средний показатель скорости подачи для определенной партии по времени. Распределение смещено влево, присутствует одна ярковыраженная и несколько маленьких вершин.
# Много выбросов с минимальными показательями. Медианная скорость подачи около 500.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.input.feed_size'],figsize=(6,3), vert=False);
plt.ylabel('Распределение размера гранул сырья сырья - Флотация ')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT") ;
plt.show;

# %%
rougher_df['rougher.input.feed_size'].describe()
# Out:
# count    19294.000000
# mean        58.970310
# std         21.634478
# min          0.046369
# 25%         47.435103
# 50%         54.610197
# 75%         65.023044
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
# Построим гистограмму
rougher_df.hist(column=['rougher.input.feed_size'], figsize=(15,5), bins=50)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Распределение значений размера гранул");

# %% [markdown]
# Размер гранул сырья - распредление смещено в право, есть явные выбросы. Медианное значение 54,5. Половина значений в пределах 47-64.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', \
                           'rougher.output.concentrate_sol', 'rougher.output.concentrate_au', 'rougher.output.tail_ag',\
                           'rougher.output.tail_pb', 'rougher.output.tail_sol',
                           'rougher.output.tail_au'],figsize=(15,10), vert=False);
plt.ylabel('Распределение параметров продукта - Флотация')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT выхода отвалов и концетратов минералов") ;
plt.show;

# %%
# Построим гистограмму Хвостов
rougher_df.hist(column=['rougher.output.tail_ag',\
                           'rougher.output.tail_pb', 'rougher.output.tail_sol',\
                           'rougher.output.tail_au'], figsize=(15,10), bins=50)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.suptitle("Распределение значений концентрации минералов в отвалах");

# %% [markdown]
# Хвосты детально исследовать не будем. Не совсем понятно это концентрация минерала в общем отвале или выходит 4 отвала. Вероятнее первый вариант. Видно, что в отвале: свинца минимум, золота побольше, а вот серебра и Sol большое количество.

# %%
# Построим гистограмму - в отношении СЕРЕБРА
rougher_df['rougher.output.concentrate_ag'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
rougher_df['rougher.input.feed_ag'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до и после флотации") ;

# %%
# Построим гистограмму - в отношении Золота
rougher_df['rougher.output.concentrate_au'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
rougher_df['rougher.input.feed_au'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до и после флотации") ;

# %%
# Построим гистограмму - в отношении Свинца
rougher_df['rougher.output.concentrate_pb'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
rougher_df['rougher.input.feed_pb'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до и после флотации") ;

# %%
# Построим гистограмму - в отношении SOL
rougher_df['rougher.output.concentrate_sol'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
rougher_df['rougher.input.feed_sol'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до и после флотации") ;

# %% [markdown]
# При сравнении концентрации минералов в исходном сырье и после флотации видно, что <b>концентрация Золота, Серебра  и Свинца увеличилась</b>. <b>Cодержание SOL уменьшилось.</b> Скорее всего SOL - это соли. В отвал ушло много SOL. Также видны выбросы. Можно сказать, что распредления начало нормализовываться, но все еще есть смещения.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.output.recovery'],figsize=(8,6), vert=False);
plt.ylabel('Эффектифность обогащения чернового концентрата ')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT эффективности обогащения") ;
plt.show;

# %%
rougher_df['rougher.output.recovery'].describe()
# Out:
# count    19439.000000
# mean        83.328587
# std         14.148086
# min          0.000000
# 25%         81.037957
# 50%         86.188892
# 75%         90.010670
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %%
# Построим гистограмму показателя эффективности обогащения чернового концентрата
rougher_df.hist(column=['rougher.output.recovery'], figsize=(8,8), bins=50)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма распределения значений показателя обогащения") ;

# %% [markdown]
# <b>Показателя эффективности обогащения чернового концентрата имеет распределение смешенное влево, медианное значение находится в районе 86. В целом показатель отражает качество руд подаваемых на обогащение. Отражает эффективность обогощения золота, судя по описанию проекта. Выбросы в районе 60-70.</b>

# %% [markdown]
# Далее идут технические признаки характеризующие количество реагентов и объема воздуха, уровня жикости на разных стадиях обогащения.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.input.floatbank10_sulfate', 'rougher.input.floatbank10_xanthate', \
'rougher.input.floatbank11_sulfate', 'rougher.input.floatbank11_xanthate'],figsize=(12,6), vert=False);
plt.ylabel('Распределение параметров продукта - Флотация')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT") ;
plt.show;

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
rougher_df.boxplot (column=['rougher.state.floatbank10_a_air', 'rougher.state.floatbank10_a_level', \
                           'rougher.state.floatbank10_b_air', 'rougher.state.floatbank10_b_level', \
                           'rougher.state.floatbank10_c_air', 'rougher.state.floatbank10_c_level',\
                           'rougher.state.floatbank10_d_air', 'rougher.state.floatbank10_d_level',\
                           'rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_e_level',\
                           'rougher.state.floatbank10_f_air', 'rougher.state.floatbank10_f_level'],figsize=(15,10), vert=False);

plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма распределения параметров флотации BOX-PLOT") ;
plt.show;

# %% [markdown]
# Также похоже на то, что в зависимости от качества входного сырья алгоритм меняет алгоритм флотации, меняет количество реагентов и других параметров. Большое количество выбросов.

# %%
df_full['date'].head(24)
# Out:
# 0     2016-01-15 00:00:00
# 1     2016-01-15 01:00:00
# 2     2016-01-15 02:00:00
# 3     2016-01-15 03:00:00
# 4     2016-01-15 04:00:00
# 5     2016-01-15 05:00:00
# 6     2016-01-15 06:00:00
# 7     2016-01-15 07:00:00
# 8     2016-01-15 08:00:00
# 9     2016-01-15 09:00:00
# 10    2016-01-15 10:00:00
# 11    2016-01-15 11:00:00
# 12    2016-01-15 12:00:00
# 13    2016-01-15 13:00:00
# 14    2016-01-15 14:00:00
# 15    2016-01-15 15:00:00
# 16    2016-01-15 16:00:00
# 17    2016-01-15 17:00:00
# 18    2016-01-15 18:00:00
# 19    2016-01-15 19:00:00
# 20    2016-01-15 20:00:00
# 21    2016-01-15 21:00:00
# 22    2016-01-15 22:00:00
# 23    2016-01-15 23:00:00
# Name: date, dtype: object

# %%
df_full['date'].sample(10)
# Out:
# 8625     2017-03-06 04:59:59
# 2371     2016-05-16 18:59:59
# 1849     2016-04-17 05:00:00
# 8737     2017-03-11 01:59:59
# 7031     2016-12-19 22:59:59
# 13330    2017-10-16 08:59:59
# 9970     2017-05-06 04:59:59
# 773      2016-02-19 15:00:00
# 11576    2017-07-27 16:59:59
# 5064     2016-09-19 04:59:59
# Name: date, dtype: object

# %% [markdown]
# #### Выводы по этапу флотации

# %% [markdown]
# <p>Судя по имеющимся данным каждый час происходит замер либо опрос датчиков и сбор показателей. Учитавая, что у многих производственных линий есть показатель норма выхода подукта в час. Скорее всего данные собираются в течении часа, а потом записываются (последовательный процесс). Возможен и другой вариант происходит паралельный-одновременный опрос датчиков каждый час, что не совсем логично (не посчитаешь эффективность).</p>
# <p>Линия обогащения судя по признаку дата работает круглые сутки, в несколько смен (трудовое законодательство). Изменения в показателях в зависимости от времени не заметил.   </p>
# <p>Далее по корреляции.</p>
# <p>Из данного датафрейма видно, что на этапе флотации происходит расчет количества реагентов, на основе параметров исходного сырья, далее подача сырья в флотационную установку. В данной установке происходит дважды добавление реагентов и многоступенчатое изменение объема воздуха и уровня жидкости. В итоге на выходе появляются концентраты ag, pb, sol, au и такие же анлогичные хвосты.</p>
#
# <p>Из тепловой карты корреляции видна слабая линейна взаимозависимость между параметрами скорости подачи сырья и добавлением концентратов, а также слабые линенейные зависимости на входе в содержании металлов в сырье и на выходы концентратов металлов между собой.</p>
#
# <p>Также видна средняя обратная зависимость между параметром rougher.calculation.au_pb_ratio и параметром сырья содержащего свинец. И есть линейные зависимости выше средней между параметрами входной продукции серебра и свинца, золота и свинца.</p>
#
# <p>И более чем логично, показатель rougher.output.recovery имеет выше средней корреляцию (линейную зависимость) с выходом параметров концентрата металлов.</p>
#
# <p>Также видно, что между параметрами уровня воды и жидкости присутствует высокая линейная зависимость.</p>
#
# <p>Кроме того, присутствует масса иных слабых зависимостей линейных и обратных между параметрами, которые решил не описывать.</p>
# <p>В расчетных характеристиках сырья, видны выбросы, очень похожие на ономальные значения (особенно в Feed_sol). Все распределения имеют минимум по два горба (моды). В этих признаках была перекрестная корреляция. Возможно содержание одного влияет на содержание другого, либо данные моды также могут отражать содержание металлов в руде. Руда из разных мест имеет разные концентрации. Также можно отметить, что содержание входного сырья Feed_sol многократно превышает значения других металлов. </p>
#
# Содержание металлов на входе:
# - серебро от 4 до 14
# - свинец от 1 до 7
# - золото от 4 до 13
# - sol от 20 до 45
#
# <p>Предположим, что данный признак это средний показатель скорости подачи для определенной партии по времени. Распределение смещено влево, присутствует одна ярковыраженная и несколько маленьких вершин.
# Много выбросов с минимальными показательями. Медианная скорость подачи около 500.</p>
# <p>Размер гранул сырья - распредление смещено в право, есть явные выбросы. Медианное значение 54,5. Половина значений в пределах 47-64.</p>
# <p>Хвосты детально исследовать не будем. Не совсем понятно это концентрация минерала в общем отвале или выходит 4 отвала. Вероятнее первый вариант. Видно, что в отвале: свинца минимум, золота побольше, а вот серебра и Sol большое количество.</p>
# <p>При сравнении концентрации минералов в исходном сырье и после флотации видно, что <b>концентрация Золота, Серебра и Свинца увеличилась. Cодержание SOL уменьшилось.</b> Скорее всего SOL - это соли. В отвал ушло много SOL. Также видны выбросы. Можно сказать, что распредления начало нормализовываться, но все еще есть смещения.<p>
# <b>Показателя эффективности обогащения чернового концентрата имеет распределение смещенное влево, медианное значение находится в районе 86. В целом показатель отражает качество руд подаваемых на обогащение. Отражает эффективность обогощения золота, судя по описанию проекта. Выбросы в районе 60-70.</b>
# <p>Также имеются технические признаки характеризующие количество реагентов и, объем воздуха и уровня жикости на разных стадиях обогащения (детально не описываю).</p>

# %% [markdown]
# ### Рассмотрим этап первичной очистки

# %%
# Выделим в отдельный датафрейм данные Первого этапа 
primary_cleaner_df = df_full[[x for x in df_full.columns if 'primary_cleaner' in x]]

# %%
primary_cleaner_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 20 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   primary_cleaner.input.sulfate             19415 non-null  float64
#  1   primary_cleaner.input.depressant          19402 non-null  float64
#  2   primary_cleaner.input.feed_size           19439 non-null  float64
#  3   primary_cleaner.input.xanthate            19335 non-null  float64
#  4   primary_cleaner.output.concentrate_ag     19439 non-null  float64
#  5   primary_cleaner.output.concentrate_pb     19323 non-null  float64
#  6   primary_cleaner.output.concentrate_sol    19069 non-null  float64
#  7   primary_cleaner.output.concentrate_au     19439 non-null  float64
#  8   primary_cleaner.output.tail_ag            19435 non-null  float64
#  9   primary_cleaner.output.tail_pb            19418 non-null  float64
# ...

# %%
# Добавляем наглядности к корреляции
corrmat = primary_cleaner_df.corr()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corrmat,  square=True)
plt.xlabel("Признаки")
plt.ylabel("Признаки")
plt.title("Тепловая карта корреляции признаков") ;

# %% [markdown]
# На диаграме видны коррелирующиеся признаки например присутствует линейная зависимость реагента - сульфата и концетрата минералов на выходе. Другие реагенты, тоже имеют слабую линейную зависимость с качеством выхода концентрата.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.input.depressant', \
                           'primary_cleaner.input.xanthate'],figsize=(15,5), vert=False);
plt.ylabel('Распределение реагентов - Первичная очистка')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма распределения реагентов BOX-PLOT") ;
plt.show;

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.input.sulfate'],figsize=(15,5), vert=False);
plt.ylabel('Распределение реагентов - Первичная очистка')
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма распределение реагента сульфат BOX-PLOT") ;
plt.show;

# %% [markdown]
# Распределение значений реагентов имеют смещение вправо, а также выбросы.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.input.feed_size'],figsize=(15,5), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма размера гранул на первичной очистке BOX-PLOT") ;
plt.show;

# %% [markdown]
# Размер гранул сырья уменьшился после первичной очистки.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.state.floatbank8_a_level', 'primary_cleaner.state.floatbank8_b_level', \
                           'primary_cleaner.state.floatbank8_c_level','primary_cleaner.state.floatbank8_d_level'], \
                            figsize=(15,10), vert=False);
plt.ylabel('Этапы очистки - Первичная очистка')
plt.xlabel("Значения")
plt.title("Диаграмма BOX-PLOT этапы очистки, уровень воды - Первичная очистка") ;
plt.show;

# %% [markdown]
# С подачей жидкости на этапе первичной очистки что-то не то, очень много выбросов.

# %%
# Построим гистограмму
primary_cleaner_df.hist(column=['primary_cleaner.state.floatbank8_a_level', 'primary_cleaner.state.floatbank8_b_level', \
                           'primary_cleaner.state.floatbank8_c_level','primary_cleaner.state.floatbank8_d_level'], figsize=(15,5), bins=50)
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.suptitle("Распределение значений уровня воды на этапах первичной очистки");

# %% [markdown]
# Есть случаи когда значения сильно отличается от моды.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.state.floatbank8_a_air', \
                           'primary_cleaner.state.floatbank8_b_air', \
                           'primary_cleaner.state.floatbank8_c_air', \
                           'primary_cleaner.state.floatbank8_d_air',],figsize=(15,10), vert=False);
plt.ylabel('Этапы очистки - Первичная очистка')
plt.xlabel("Значения")
plt.title("Диаграмма BOX-PLOT подача воздуха на этапах первичной очистки") ;
plt.show;

# %% [markdown]
# Признаки характеризующие подачу воздуха на этапе первичной очистки имеют аномальные выбросы.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.output.concentrate_ag', \
                           'primary_cleaner.output.concentrate_pb', \
                           'primary_cleaner.output.concentrate_sol', \
                           'primary_cleaner.output.concentrate_au',],figsize=(15,10), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT выход концентрата на этапе певичной очистке") 
plt.show;

# %%
# Построим гистограмму - в отношении СЕРЕБРА
df_full['rougher.input.feed_ag'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
df_full['rougher.output.concentrate_ag'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
df_full['primary_cleaner.output.concentrate_ag'].hist(figsize=(15,10), bins=50, alpha=0.5, color='red')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до, после флотации, после первичной очистки") ;

# %%
# Построим гистограмму - в отношении Золота
df_full['rougher.output.concentrate_au'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
df_full['rougher.input.feed_au'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.concentrate_au'].hist(figsize=(15,10), bins=50, alpha=0.5, color='red')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до, после флотации, после первичной очистки") ;

# %%
# Построим гистограмму - в отношении Свинца
df_full['rougher.output.concentrate_pb'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
df_full['rougher.input.feed_pb'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.concentrate_pb'].hist(figsize=(15,10), bins=50, alpha=0.5, color='red')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до, после флотации, после первичной очистки") ;

# %%
# Построим гистограмму - в отношении SOL
df_full['rougher.output.concentrate_sol'].hist(figsize=(15,10), bins=50, alpha=0.5, color='green')
df_full['rougher.input.feed_sol'].hist(figsize=(15,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.concentrate_sol'].hist(figsize=(15,10), bins=50, alpha=0.5, color='red')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала до, после флотации, после первичной очистки") ;

# %% [markdown]
# После первичной очистки содержание серебра и sol в концентрате значительно уменьшилось. При этом содержание золота и свинца значительно увеличилось. <b>Содержание золота выросло в среднем выросло на 70%.</b>

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
primary_cleaner_df.boxplot (column=['primary_cleaner.output.tail_ag', \
                           'primary_cleaner.output.tail_pb', \
                           'primary_cleaner.output.tail_sol', \
                           'primary_cleaner.output.tail_au',],figsize=(15,10), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT содержание минералов в отвалах") ;
plt.show;

# %%
# Построим гистограмму Хвостов
cols_1 = ['rougher.output.tail_ag','rougher.output.tail_pb', 'rougher.output.tail_sol',\
                           'rougher.output.tail_au']
rougher_df[cols_1].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.suptitle("Распределение значений концентрации минералов в отвалах на этапе флотации и первичной очистки");   
cols_2 = ['primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb', 'primary_cleaner.output.tail_sol', \
                           'primary_cleaner.output.tail_au',]
primary_cleaner_df[cols_2].hist(figsize=(10,5), bins=50, alpha=0.5, color='red')
plt.xlabel("Значения")
plt.ylabel("Количество");

# %% [markdown]
# В отвалах выросло содержание серебра, свинца и незначительно золота. Содержание SOL уменьшилось. Значительное количество выбросов значений также продолжает присутствовать.

# %% [markdown]
# #### Выводы по результатам первичной очистки
# <p>На диаграме видны коррелирующиеся признаки например присутствует линейная зависимость реагента - сульфата и концетрата минералов на выходе. Другие реагенты, тоже имеют слабую линейную зависимость с качеством выхода концентрата. </p>
# <p>Распределение значений реагентов имеют смещение вправо, а также присутствуют выбросы. </p>
# Размер гранул сырья уменьшился после флотации.</p>
# <p>С подачей жидкости на этапе первичной очистки что-то не то, очень много выбросов. Есть случаи когда значения сильно отличается от моды. </p>
# <p>Признаки характеризующие подачу воздуха на этапе первичной очистки имеют аномальные выбросы.
# <p>После первичной очистки содержание серебра и sol в концентрате значительно уменьшилось. При этом содержание золота и свинца значительно увеличилось. <b>Содержание золота выросло в среднем выросло на 70%.</b></p>
# <p>В отвалах выросло содержание серебра, свинца и незначительно золота. Содержание SOL уменьшилось. Значительное количество выбросов в распределениях также продолжает присутствовать.</p>

# %% [markdown]
# ### Рассмотрим этап вторичной очистки

# %%
# Выделим в отдельный датафрейм данные Первого этапа 
secondary_cleaner_df = df_full[[x for x in df_full.columns if 'secondary_cleaner' in x]]

# %%
secondary_cleaner_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   secondary_cleaner.output.tail_ag            19437 non-null  float64
#  1   secondary_cleaner.output.tail_pb            19427 non-null  float64
#  2   secondary_cleaner.output.tail_sol           17691 non-null  float64
#  3   secondary_cleaner.output.tail_au            19439 non-null  float64
#  4   secondary_cleaner.state.floatbank2_a_air    19219 non-null  float64
#  5   secondary_cleaner.state.floatbank2_a_level  19438 non-null  float64
#  6   secondary_cleaner.state.floatbank2_b_air    19416 non-null  float64
#  7   secondary_cleaner.state.floatbank2_b_level  19438 non-null  float64
#  8   secondary_cleaner.state.floatbank3_a_air    19426 non-null  float64
# ...

# %%
# Добавляем наглядности к корреляции
corrmat = secondary_cleaner_df.corr()
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corrmat,  square=True)
plt.xlabel("Признаки")
plt.ylabel("Признаки")
plt.title("Тепловая карта корреляции признаков") ;

# %% [markdown]
# <p>Здесь по корреляции признаков можно отметить следующее.</p>
# <p>Показатели воздуха и воды коррелируют между собой (прямая линейная завиисмость), а также на 6 этапе влияет количество воздуха на отвалы SOL и имеют обратную зависимость на серебро и свинец. Подобный зависимости имеются и на других этапах но ониимееют более слабую корреляцию. </p>
# <p>Также признаки характеризующие количество минералов в отвалах коррелируют между собой, зависимости разнонаправлены.</p>

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
secondary_cleaner_df.boxplot (column=['secondary_cleaner.state.floatbank2_a_air', 'secondary_cleaner.state.floatbank2_b_air', \
                           'secondary_cleaner.state.floatbank3_a_air','secondary_cleaner.state.floatbank3_b_air', \
                                    'secondary_cleaner.state.floatbank4_a_air','secondary_cleaner.state.floatbank4_b_air',\
                                   'secondary_cleaner.state.floatbank5_a_air','secondary_cleaner.state.floatbank5_b_air',\
                                    'secondary_cleaner.state.floatbank6_a_air'], \
                            figsize=(15,10), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT подача воздуха на вторичном этапе очистки") ;
plt.show;

# %% [markdown]
# На диаграмме видно поэтапное уменьшение количество воздуха, и рост на последнем этапе. На данном этапе писутствует значительная корреляция с признаками характиризующими содержание минералов в отвалах.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
secondary_cleaner_df.boxplot (column=['secondary_cleaner.state.floatbank2_a_level', 'secondary_cleaner.state.floatbank2_b_level', \
                           'secondary_cleaner.state.floatbank3_a_level','secondary_cleaner.state.floatbank3_b_level', \
                                    'secondary_cleaner.state.floatbank4_a_level','secondary_cleaner.state.floatbank4_b_level',\
                                   'secondary_cleaner.state.floatbank5_a_level','secondary_cleaner.state.floatbank5_b_level',\
                                    'secondary_cleaner.state.floatbank6_a_level'], \
                            figsize=(15,10), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT уровень воды на этапах вторичной очистки") ;
plt.show;

# %% [markdown]
# Здесь также почти на всех этапах уровень воды в пределах медианы и только 4_b показывает плавающее значение.

# %%
# Построим гистограмму Хвостов - Серебра
df_full['rougher.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['secondary_cleaner.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах после флотации, после первичной очистки, после вторичной очистки") ;

# %%
# Построим гистограмму Хвостов - Свинца
df_full['rougher.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black');
df_full['primary_cleaner.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green');
df_full['secondary_cleaner.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange');
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах после флотации, после первичной очистки, после вторичной очистки") ;

# %%
# Построим гистограмму Хвостов - Золота
df_full['rougher.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black');
df_full['primary_cleaner.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green');
df_full['secondary_cleaner.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange');
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах после флотации, после первичной очистки, после вторичной очистки") ;

# %%
# Построим гистограмму Хвостов - SOL
df_full['rougher.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black');
df_full['primary_cleaner.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green');
df_full['secondary_cleaner.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange');
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах после флотации, после первичной очистки, после вторичной очистки") ;

# %% [markdown]
# На этапе вторичной очистки в отвалах значительно выросло содержание SOL и свинца, незначительно золота. Кроме того, незначительно упало содержание серебра.

# %% [markdown]
# #### Выводы по этапу вторичной очистки
# <p>Здесь по корреляции признаков можно отметить следующее.</p>
# <p>Показатели воздуха и воды коррелируют между собой (прямая линейная завиисмость), а также на 6 этапе влияет количество воздуха на отвалы SOL и имеют обратную зависимость на серебро и свинец. Подобный зависимости имеются и на других этапах но ониимееют более слабую корреляцию. </p>
# <p>Также признаки характеризующие количество минералов в отвалах коррелируют между собой, зависимости разнонаправлены.</p>
# <p>На диаграмме видно поэтапное уменьшение количество воздуха, и рост на последнем этапе. </p>
# <p>На данном этапе писутствует значительная корреляция с признаками характиризующими содержание минералов в отвалах.</p>
# <p>Здесь также почти на всех этапах уровень воды в пределах медианы и только 4_b показывает плавающее значение.</p>
# <p>На этапе вторичной очистки в отвалах значительно <b> выросло содержание SOL и свинца, незначительно золота. Кроме того, незначительно упало содержание серебра.</b></p>

# %% [markdown]
# ### Завершающий этап на котором получаем - Финальные характеристики, сравнение средних и распределений

# %%
# Выделим в отдельный датафрейм данные Первого этапа 
final_df = df_full[[x for x in df_full.columns if 'final' in x]]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   final.output.concentrate_ag   19438 non-null  float64
#  1   final.output.concentrate_pb   19438 non-null  float64
#  2   final.output.concentrate_sol  19228 non-null  float64
#  3   final.output.concentrate_au   19439 non-null  float64
#  4   final.output.recovery         19439 non-null  float64
#  5   final.output.tail_ag          19438 non-null  float64
#  6   final.output.tail_pb          19338 non-null  float64
#  7   final.output.tail_sol         19433 non-null  float64
#  8   final.output.tail_au          19439 non-null  float64
# dtypes: float64(9)
# memory usage: 1.3 MB

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
final_df.boxplot (column=['final.output.concentrate_ag', \
                           'final.output.concentrate_pb', \
                           'final.output.concentrate_sol', \
                           'final.output.concentrate_au',],figsize=(12,7), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT содержание минералов в концентрате на финальной стадии") ;
plt.show;

# %%
# Построим гистограмму - в отношении СЕРЕБРА
df_full['rougher.input.feed_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['rougher.output.concentrate_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['primary_cleaner.output.concentrate_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='red')
df_full['final.output.concentrate_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации СЕРЕБРА до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму - в отношении Свинца
df_full['rougher.input.feed_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['rougher.output.concentrate_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['primary_cleaner.output.concentrate_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='red')
df_full['final.output.concentrate_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации Свинца до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму - в отношении SOL
df_full['rougher.input.feed_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['rougher.output.concentrate_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['primary_cleaner.output.concentrate_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='red')
df_full['final.output.concentrate_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации SOL до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму - в отношении Золота
df_full['rougher.input.feed_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['rougher.output.concentrate_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['primary_cleaner.output.concentrate_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='red')
df_full['final.output.concentrate_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации Золота до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Посчитаем медиану
df_full['final.output.concentrate_au'].median()
# Out:
# 45.01124391455689

# %% [markdown]
# В концентрате сократилось содержание серебра, содержание свинца и SOL осталось примерно на том же уровне, но и самое важное, для чего собственно и был весь процесс, <b>содержание золота увеличилось до 45</b>.
# Также в распределении золото присутствует длинное предгорье (выбросы) слева, указывающие на то, что существует множество случаев когда золота в конечном продукте было низкое содержание. Причины могут быть разные, от незкого содержания минералов в руде, до плохого алгоритма обогащения.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
final_df.boxplot (column=['final.output.tail_ag', \
                           'final.output.tail_pb', \
                           'final.output.tail_sol', \
                           'final.output.tail_au',],figsize=(15,7), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT концентрация минералов в отвалах на финальной стадии") ;
plt.show;

# %%
# Построим гистограмму Хвостов - Серебра
df_full['rougher.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['secondary_cleaner.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange')
df_full['final.output.tail_ag'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму Хвостов - Свинца
df_full['rougher.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['secondary_cleaner.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange')
df_full['final.output.tail_pb'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму Хвостов - Золота
df_full['rougher.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['secondary_cleaner.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange')
df_full['final.output.tail_au'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %%
# Построим гистограмму Хвостов - SOL
df_full['rougher.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='black')
df_full['primary_cleaner.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='green')
df_full['secondary_cleaner.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='orange')
df_full['final.output.tail_sol'].hist(figsize=(10,5), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения концентрации минерала в отвалах до и после флотации, после первичной очистки, после вторичной и финальной очистки") ;

# %% [markdown]
# В отвалах по сравнению с предыдущими этапами уменьшилось содержание всех минералов.

# %%
# Посмотрим на распределение значений через диаграмму BOX PLOT
df_full.boxplot (column=['rougher.output.recovery', 'final.output.recovery'],figsize=(8,6), vert=False);
plt.xlabel("Значения")
plt.ylabel("Название признаков")
plt.title("Диаграмма BOX-PLOT эффективности обогащения чернового концентрата") ;
plt.show;

# %%
df_full['rougher.output.recovery'].describe()
# Out:
# count    19439.000000
# mean        83.328587
# std         14.148086
# min          0.000000
# 25%         81.037957
# 50%         86.188892
# 75%         90.010670
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %%
df_full['final.output.recovery'].describe()
# Out:
# count    19439.000000
# mean        67.050208
# std         10.125840
# min          0.000000
# 25%         63.299712
# 50%         68.172738
# 75%         72.686642
# max        100.000000
# Name: final.output.recovery, dtype: float64

# %%
# Построим гистограмму показателя эффективности обогащения чернового концентрата
rougher_df['rougher.output.recovery'].hist(figsize=(8,4), bins=50, alpha=0.5, color='red')
final_df['final.output.recovery'].hist(figsize=(8,4), bins=50, alpha=0.5, color='yellow')
plt.xlabel("Значения")
plt.ylabel("Количество")
plt.title("Диаграмма сравнения показателей эффективности обогащения") ;

# %% [markdown]
# На вышеуказанных диаграммах видно, что эффективноть обогащения на финальной стадии снизилась до 68 (медианное значение). При этом снизился показатель стандартного отклонения, что говорит о нормализации распределения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Достаточно подробный анализ - восхищаюсь количество уделённого этому времени:)

# %% [markdown]
# Перед тем как приступать к моделированию сравним средние распределений размеров гранул. В обучающей и тестовой выборках. Согласно заданию.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Аналогично если идём по пути гипотез, то нужно:
# - сформулировать гипотезы;
# - обосновать инструментарий - почему применяем `ttest` и можем ли вообще.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Мне кажется ttest можно испольховать, т.к. он покажет отличаются ли средние значения распредлений или нет. В задании проди просили сравнить это. Я удалил т.к. диаграмм достаточно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Да, диаграмм будет достаточно. По поводу `ttest` оставил коммент выше.

# %%
# Построим гистограммы размера гранул
df_train_good['primary_cleaner.input.feed_size'].hist(figsize=(8,4), bins=50, alpha=0.5, color='red', density=True)
df_test['primary_cleaner.input.feed_size'].hist(figsize=(8,4), bins=50, alpha=0.5, color='yellow', density=True)
plt.xlabel("Количество")
plt.ylabel("Плотность")
plt.title("Диаграмма плотности вероятности сравнения размера гранул между выборками, вторичная очистка") ;

# %%
sns.kdeplot(
   data=df_train_good, x="primary_cleaner.input.feed_size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
sns.kdeplot(
   data=df_test, x="primary_cleaner.input.feed_size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
plt.xlabel("Количество")
plt.ylabel("Плотность")
plt.title("Диаграмма плотности вероятности сравнения размера гранул между выборками, вторичная очистка") ;

# %%
# Построим гистограмму показателя эффективности обогащения чернового концентрата
df_train_good['rougher.input.feed_size'].hist(figsize=(8,4), bins=50, alpha=0.5, color='red', density=True)
df_test['rougher.input.feed_size'].hist(figsize=(8,4), bins=50, alpha=0.5, color='yellow', density=True)
plt.xlabel("Количество")
plt.ylabel("Плотность")
plt.title("Диаграмма плотности вероятности сравнения размера гранул в разных выборках") ;

# %%
sns.kdeplot(
   data=df_train_good, x="rougher.input.feed_size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
sns.kdeplot(
   data=df_test, x="rougher.input.feed_size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
plt.xlabel("Количество")
plt.ylabel("Плотность")
plt.title("Диаграмма плотности вероятности сравнения размера гранул между выборками, вторичная очистка") ;

# %% [markdown]
# Визуально схожесть присутствует.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сравнили размеры гранул сырья на обучающей и тестовой выборках для этапов `rougher.input.feed_size` и `primary_cleaner.input.feed_size` - отлично.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Здесь мы имеем дело с непрерывной величиной - для анализа её распределения стоит использовать график распределения плотности `kde` (например, `sns.kdeplot`) вместо обычной гистограммы.
#
# Тут также важно помнить, что `ttest` зависит от размера дисперсии в выборках и от наличия в выборках выбросов, поэтому он вполне может показать наличие разницы между средними. Но в целом мы проверяем не равенство средних (а `ttest` как раз равенство и проверяет), а схожесть - поэтому тут будет достаточно визуальной оценки схожести и второй части вывода о том, что выборки схожи.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Ттест удален, sns.kdeplot добавлен. seaborn визуально более эффективно показывает распределение.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отлично.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Кажется, что делать целую функцию ради простого сложения трёх столбцов, с зашитыми к тому же названиями - весьма избыточно. Тут или стоит сделать функцию универсальной, или просто складывать руками.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Концентрация ценных металлов по результатам обогащения выросла.

# %%
# Ниже код для обрезки значений, сделаю не активным так как нарушается выпылнение алгоритма.
# Т.к. часть признаков берется из df_full

# %%
df_full["rougher.input.feed"] = df_full["rougher.input.feed_au"] + df_full["rougher.input.feed_ag"] + df_full["rougher.input.feed_pb"] + df_full["rougher.input.feed_sol"] 
df_full["rougher.output.concentrate"] = df_full["rougher.output.concentrate_au"] + df_full["rougher.output.concentrate_ag"] + df_full["rougher.output.concentrate_pb"] + df_full["rougher.output.concentrate_sol"]
df_full["final.output.concentrate"] = df_full["final.output.concentrate_au"] + df_full["final.output.concentrate_ag"] + df_full["final.output.concentrate_pb"] + df_full["final.output.concentrate_sol"]

# %% [raw]
# df_full = df_full[(df_full["rougher.input.feed"] > 20) & (df_full["rougher.output.concentrate"] > 20) & (df_full["final.output.concentrate"] > 20)]

# %%
total_conc = df_full[["rougher.input.feed", "rougher.output.concentrate", "final.output.concentrate"]]

# %%
fig = plt.figure(figsize=(10, 6))
for column in list(total_conc):
    sns.distplot(total_conc[column], kde=False)
plt.legend(list(total_conc))
plt.title("Общая концентрация минералов на этапах ")
plt.xlabel("Концентрация %")
plt.ylabel("Значение")
fig.show()

# %%
# Удалим новыестолбцы
df_full = df_full.drop(["rougher.input.feed", "rougher.output.concentrate", "final.output.concentrate"], axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована суммарная концентрация металлов на разных стадиях техпроцесса - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# На данном этапе следует также избавиться от аномалий: давай обратим внимание на левую сторону графика по оси Х - все ли значения, которые мы там видим, кажутся адекватными, учитвыая, что мы анализируем суммарную концентрацию сразу четырёх веществ?
#
# Также обрати внимание, что ты анализируешь суммарную концентрацию на `full` выборке, а удалить аномалии важно из `train`, так как на этой выборке мы будем обучать модели, и нам важно обеспечить её чистоту.
#
# Тут можно пойти двумя путями:
# - если из `train` уже были удалены лишние столбцы, то суммарную концентрацию напрямую не выйдет отфильтровать - в таком случае нужно удалить аномалии из `full`, а потом использовать столбец `date` для очистки `train`: в `train` нужно будет оставить только те строки, `date` которых есть в столбце `date` у `full` выборки - так как из `full` уже будут удалены аномалии, то и дата аномальных замеров будет удалена;
# - если из `train` ещё не были удалены лишние признаки, то можно очистить `train` напрямую.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Вставил код ниже в самое начало, чтобы не переписывать алгоритм.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Окей, годится:)

# %% [raw]
# # Уберем аномалии
# df_train["rougher.input.feed"] = df_train["rougher.input.feed_au"] + df_train["rougher.input.feed_ag"] + df_train["rougher.input.feed_pb"] + df_train["rougher.input.feed_sol"]
# df_train["rougher.output.concentrate"] = df_train["rougher.output.concentrate_au"] + df_train["rougher.output.concentrate_ag"] + df_train["rougher.output.concentrate_pb"] + df_train["rougher.output.concentrate_sol"]
# df_train["final.output.concentrate"] = df_train["final.output.concentrate_au"] + df_train["final.output.concentrate_ag"] + df_train["final.output.concentrate_pb"] + df_train["final.output.concentrate_sol"]
# df_train = df_train[(df_train["rougher.input.feed"] > 20) & (df_train["rougher.output.concentrate"] > 20) & (df_train["final.output.concentrate"] > 20)]
# df_train = df_train.drop(["rougher.input.feed", "rougher.output.concentrate", "final.output.concentrate"], axis=1)

# %% [markdown]
# ### Выводы по результатам анализа данных

# %% [markdown]
# <p>Судя по имеющимся данным каждый час происходит замер либо опрос датчиков и сбор показателей. Учитывая, что у многих производственных линий есть показатель норма выхода подукта в час. Скорее всего данные собираются в течении часа, а потом записываются (последовательный процесс). Возможен и другой вариант происходит паралельный-одновременный опрос датчиков каждый час, что не совсем логично (не посчитаешь эффективность).</p>
# <p>Линия обогащения судя по признаку дата работает круглые сутки, в несколько смен (трудовое законодательство). Изменения в показателях в зависимости от времени не заметил.   </p>
# <p>Далее по корреляции.</p>
# <p>Из данного датафрейма видно, что на этапе флотации происходит расчет количества реагентов, на основе параметров исходного сырья, далее подача сырья в флотационную установку. В данной установке происходит дважды добавление реагентов и многоступенчатое изменение объема воздуха и уровня жидкости. В итоге на выходе появляются концентраты ag, pb, sol, au и такие же аналогичные хвосты.</p>
#
# <p>Из тепловой карты корреляции видна слабая линейна взаимозависимость между параметрами скорости подачи сырья и добавлением концентратов, а также слабые линенейные зависимости на входе в содержании металлов в сырье и на выходы концентратов металлов между собой.</p>
#
# <p>Также видна средняя обратная зависимость между параметром rougher.calculation.au_pb_ratio и параметром сырья содержащего свинец. И есть линейные зависимости выше средней между параметрами входной продукции серебра и свинца, золота и свинца.</p>
#
# <p>И более чем логично, показатель rougher.output.recovery имеет выше средней корреляцию (линейную зависимость) с выходом параметров концентрата металлов.</p>
#
# <p>Также видно, что между параметрами уровня воды и жидкости присутствует высокая линейная зависимость.</p>
#
# <p>Кроме того, присутствует масса иных слабых зависимостей линейных и обратных между параметрами, которые решил не описывать.</p>
# <p>В расчетных характеристиках сырья, видны выбросы, очень похожие на аономальные значения (особенно в Feed_sol). Все распределения имеют минимум по два горба (моды). В этих признаках была перекрестная корреляция. Возможно содержание одного влияет на содержание другого, либо данные моды также могут отражать содержание металлов в руде. Руда из разных мест имеет разные концентрации. Также можно отметить, что содержание входного сырья Feed_sol многократно превышает значения других металлов. </p>
#
# Содержание металлов на входе:
# - серебро от 4 до 14
# - свинец от 1 до 7
# - золото от 4 до 13
# - sol от 20 до 45
#
# <p>Предположим, что данный признак это средний показатель скорости подачи для определенной партии по времени. Распределение смещено влево, присутствует одна ярко выраженная и несколько маленьких вершин.
# Много выбросов с минимальными показателями. Медианная скорость подачи около 500.</p>
# <p>Размер гранул сырья - распределение смещено в право, есть явные выбросы. Медианное значение 54,5. Половина значений в пределах 47-64.</p>
# <p>Хвосты детально исследовать не будем. Не совсем понятно это концентрация минерала в общем отвале или выходит 4 отвала. Вероятнее первый вариант. Видно, что в отвале: свинца минимум, золота побольше, а вот серебра и Sol большое количество.</p>
# <p>При сравнении концентрации минералов в исходном сырье и после флотации видно, что <b>концентрация Золота, Серебра и Свинца увеличилась. Cодержание SOL уменьшилось.</b> Скорее всего SOL - это соли. В отвал ушло много SOL. Также видны выбросы. Можно сказать, что распределение начало нормализовываться, но все еще есть смещение.<p>
# <b>Показателя эффективности обогащения чернового концентрата имеет распределение смещенное влево, медианное значение находится в районе 86. В целом показатель отражает качество руд подаваемых на обогащение. Отражает эффективность обогащения золота, судя по описанию проекта. Выбросы в районе 60-70.</b>
# <p>Также имеются технические признаки характеризующие количество реагентов и, объем воздуха и уровня жидкости на разных стадиях обогащения (детально не описываю).</p>
#
# <p>На диаграмме видны коррелирующиеся признаки например присутствует линейная зависимость реагента - сульфата и концетрата минералов на выходе. Другие реагенты, тоже имеют слабую линейную зависимость с качеством выхода концентрата. </p>
# <p>Распределение значений реагентов имеют смещение вправо, а также присутствуют выбросы. </p>
# Размер гранул сырья уменьшился после флотации.</p>
# <p>С подачей жидкости на этапе первичной очистки что-то не то, очень много выбросов. Есть случаи когда значения сильно отличается от моды. </p>
# <p>Признаки характеризующие подачу воздуха на этапе первичной очистки имеют аномальные выбросы.
# <p>После первичной очистки содержание серебра и sol в концентрате значительно уменьшилось. При этом содержание золота и свинца значительно увеличилось. <b>Содержание золота в среднем выросло на 70%.</b></p>
# <p>В отвалах выросло содержание серебра, свинца и незначительно золота. Содержание SOL уменьшилось. Значительное количество выбросов в распределениях также продолжает присутствовать.</p>
#
#
# <p>Здесь по корреляции признаков можно отметить следующее.</p>
# <p>Показатели воздуха и воды коррелируют между собой (прямая линейная зависимость), а также на 6 этапе влияет количество воздуха на отвалы SOL и имеют обратную зависимость на серебро и свинец. Подобный зависимости имеются и на других этапах но они имееют более слабую корреляцию. </p>
# <p>Также признаки характеризующие количество минералов в отвалах коррелируют между собой, зависимости разнонаправлены.</p>
# <p>На диаграмме видно поэтапное уменьшение количество воздуха, и рост на последнем этапе. </p>
# <p>На данном этапе присутствует значительная корреляция с признаками характеризующими содержание минералов в отвалах.</p>
# <p>Здесь также почти на всех этапах уровень воды в пределах медианы и только 4_b показывает плавающее значение.</p>
# <p>На этапе вторичной очистки в отвалах значительно <b> выросло содержание SOL и свинца, незначительно золота. Кроме того, незначительно упало содержание серебра.</b></p>
#
#
# <p>В концентрате сократилось содержание серебра, содержание свинца и SOL осталось примерно на том же уровне, но и самое важное, для чего собственно и был весь процесс, <b>содержание золота увеличилось до 45</b>.</p>
# <p>Также в распределении золото присутствует длинное предгорье (выбросы) слева, указывающие на то, что существует множество случаев когда золота в конечном продукте было низкое содержание. Причины могут быть разные, от низкого содержания минералов в руде, до плохого алгоритма обогащения.</p>
# <p>В отвалах по сравнению с предыдущими этапами уменьшилось содержание всех минералов.</p>
# <p>На вышеуказанных диаграммах видно, что эффективность обогащения на финальной стадии снизилась до 68 (медианное значение). При этом снизился показатель стандартного отклонения, что говорит о нормализации распределения.</p>
# <p>Размер гранул на обучающей и тестовой выборках визуально совпадают.</p>
# <p><b>Концентрация ценных металлов по результатам обогащения выросла.</p></b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Вывод, конечно, ух! Прям на полпроекта:) Отлично!

# %% [markdown]
# ## Модель

# %% [markdown]
# Напишим функцию для подсчета sMAPE

# %%
def sMAPE(target, predict):
    
    deviation = abs(target - predict)
    average = (abs(target)+abs(predict))/2
    result = np.mean(deviation/average)*100
    
    return result

# %%
print(sMAPE(rougher_df['rougher.output.recovery'], final_df['final.output.recovery'] ))
# Out:
# 28.50235265354137

# %%
print(sMAPE(rougher_df['rougher.output.recovery'], rougher_df['rougher.output.recovery'] ))
# Out:
# 0.0

# %% [markdown]
# Функция работает правильно.

# %%
# Полная функция
def full_smape(target_1, predict_1, target_2, predict_2):
    smape_1 = sMAPE(target_1, predict_1)
    smape_2 = sMAPE(target_2, predict_2)

    return (smape_1*0.25) + (smape_2*0.75)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функции для частного и взвешенного `sMAPE` - супер!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Некритично, но всё же: названия переменных транслитом с русского языка - некорректное решение, которое может ввести в ступор твоих англоязычных коллег и точно вызовет осуждение у русскоязычных:)
#
# Переменные стоит именовать англоязычными терминами - стандарт отрасли:)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Давай ещё немного в оптимизацию: раз у нас уже есть функция `sMAPE`, то вместо хардкодного расчёта метрики в `full_smape`, повторяющегося два раза, можно эту же функцию внутри функции `full_smape`, вроде:
#
#     def full_smape(target, predict, target_final, predict_final):
#
#     smape_1 = sMAPE(target_1, predict_1)
#     smape_2 = sMAPE(target_2, predict_2)
#
#     return (smape_1*0.25) + (smape_2*0.75)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Рекомендации и функцию исправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
full_smape(rougher_df['rougher.output.recovery'], final_df['final.output.recovery'],rougher_df['rougher.output.recovery'], final_df['final.output.recovery'])
# Out:
# 28.50235265354137

# %%
# Подготовим выборки для обучения моделей
features_rougher = df_train_good[[x for x in df_train_good.columns if 'rougher' in x]]
target_rougher = df_train['rougher.output.recovery']
no_in_final = list(filter(lambda x: x in features_rougher, df_train_good))
features_final = df_train_good.drop(columns=no_in_final, axis=1)
target_final = df_train['final.output.recovery']
features_final = features_final.drop(columns='date', axis=1)

# %%
features_rougher.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13741 entries, 0 to 14148
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   rougher.input.feed_ag               13741 non-null  float64
#  1   rougher.input.feed_pb               13741 non-null  float64
#  2   rougher.input.feed_rate             13741 non-null  float64
#  3   rougher.input.feed_size             13741 non-null  float64
#  4   rougher.input.feed_sol              13741 non-null  float64
#  5   rougher.input.feed_au               13741 non-null  float64
#  6   rougher.input.floatbank10_sulfate   13741 non-null  float64
#  7   rougher.input.floatbank10_xanthate  13741 non-null  float64
#  8   rougher.input.floatbank11_sulfate   13741 non-null  float64
#  9   rougher.input.floatbank11_xanthate  13741 non-null  float64
#  10  rougher.state.floatbank10_a_air     13741 non-null  float64
# ...

# %%
target_rougher.shape
# Out:
# (13741,)

# %%
target_rougher.head()
# Out:
# 0    87.107763
# 1    86.843261
# 2    86.842308
# 3    87.226430
# 4    86.688794
# Name: rougher.output.recovery, dtype: float64

# %%
features_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13741 entries, 0 to 14148
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   primary_cleaner.input.sulfate               13741 non-null  float64
#  1   primary_cleaner.input.depressant            13741 non-null  float64
#  2   primary_cleaner.input.feed_size             13741 non-null  float64
#  3   primary_cleaner.input.xanthate              13741 non-null  float64
#  4   primary_cleaner.state.floatbank8_a_air      13741 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_level    13741 non-null  float64
#  6   primary_cleaner.state.floatbank8_b_air      13741 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_level    13741 non-null  float64
#  8   primary_cleaner.state.floatbank8_c_air      13741 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# А почему бы ни включить сюда ещё и `rougher`?

# %%
target_final.shape
# Out:
# (13741,)

# %%
target_final.head()
# Out:
# 0    70.541216
# 1    69.266198
# 2    68.116445
# 3    68.347543
# 4    66.927016
# Name: final.output.recovery, dtype: float64

# %%
# Подготовим выборки для обучения моделей
features_test_rougher = df_test[[x for x in df_test.columns if 'rougher' in x]]
no_in_test_final = list(filter(lambda x: x in features_test_rougher, df_test))
features_test_final = df_test.drop(columns=no_in_test_final, axis=1)
features_test_final = features_test_final.drop(columns='date', axis=1)

# %%
features_test_rougher.head()
# Out:
#    rougher.input.feed_ag  rougher.input.feed_pb  rougher.input.feed_rate  \
# 0              13.128569               5.636710               489.793655
# 1              13.036280               5.526065               490.104534
# 2              13.138412               5.426561               489.617969
# 3              12.400507               5.114758               476.618130
# 4              11.327427               4.767383               488.248117
#
#    rougher.input.feed_size  rougher.input.feed_sol  rougher.input.feed_au  \
# 0                62.710452               42.022440              12.084103
# 1                61.961163               41.187903              11.918977
# 2                66.903807               42.546294              12.091332
# 3                59.865919               41.060195              12.181597
# 4                63.315324               41.269161              11.290425
#
#    rougher.input.floatbank10_sulfate  rougher.input.floatbank10_xanthate  \
# ...

# %%
features_test_final.shape
# Out:
# (5290, 30)

# %% [markdown]
# Теперь достанем 2 целевых признака для тестовых данных

# %%
# Восстановим целый тестовый фрейм
df_test_full = df_full[df_full['date'].isin(df_test['date'])]

# %%
df_test_full.head()
# Out:
#                      date  final.output.concentrate_ag  \
# 4682  2016-09-01 00:59:59                     7.578381
# 4683  2016-09-01 01:59:59                     7.813838
# 4684  2016-09-01 02:59:59                     7.623392
# 4685  2016-09-01 03:59:59                     8.552457
# 4686  2016-09-01 04:59:59                     8.078781
#
#       final.output.concentrate_pb  final.output.concentrate_sol  \
# 4682                    10.466295                     11.990938
# 4683                    10.581152                     12.216172
# 4684                    10.424024                     12.313710
# 4685                    10.503229                     13.074570
# 4686                    10.222788                     12.475427
#
#       final.output.concentrate_au  final.output.recovery  \
# 4682                    40.743891              70.273583
# 4683                    39.604292              68.910432
# 4684                    40.724190              68.143213
# ...

# %%
df_test_full.shape
# Out:
# (5290, 87)

# %%
# Сформировали целевой признак
target_test_rougher = df_test_full['rougher.output.recovery']
target_test_final = df_test_full['final.output.recovery']

# %%
target_test_rougher.shape
# Out:
# (5290,)

# %%
target_test_rougher.head()
# Out:
# 4682    89.993421
# 4683    88.089657
# 4684    88.412756
# 4685    87.360133
# 4686    83.236367
# Name: rougher.output.recovery, dtype: float64

# %%
target_test_final.shape
# Out:
# (5290,)

# %%
target_test_final.head()
# Out:
# 4682    70.273583
# 4683    68.910432
# 4684    68.143213
# 4685    67.776393
# 4686    61.467078
# Name: final.output.recovery, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выделили признаки для обучения и целевые признаки - отлично!
# </div>

# %%
# Стандартизируем данные

pd.options.mode.chained_assignment = None

scaler = StandardScaler()
scaler.fit(features_rougher)
features_rougher = scaler.transform(features_rougher)

scaler = StandardScaler()
scaler.fit(features_final)
features_final = scaler.transform(features_final)

# %% [markdown]
# Стандартизация ухудшает показатели - отключил. В предыдущих поектах она просто не улучшала.

# %% [markdown]
# Данные готовы можно обучать модели.

# %% [markdown]
# ### Построим модель Линейной Регрессии

# %%
# Создадим скоринг на осове функции sMAPE
smape = make_scorer(sMAPE, greater_is_better=True)

# %%
# %%time
# Модель для флотации
model_1 = LinearRegression()
# Модель для иных этапов
model_2 = LinearRegression()

# Расчет значений на кросвалидации
scores = cross_val_score(model_1, features_rougher, target_rougher, cv=5, n_jobs=-1, verbose=10, scoring=smape)
final_score_1 = pd.Series(scores).mean()
scores = cross_val_score(model_2, features_final, target_final, cv=5, n_jobs=-1, verbose=10, scoring=smape)
final_score_2 = pd.Series(scores).mean()
final_score = abs(final_score_1)*0.25 + abs(final_score_2)*0.75
print('Средняя оценка качества модели:', final_score)
# Out:
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] START .....................................................................
# [CV] END ................................ score: (test=8.105) total time=   0.0s
# [CV] START .....................................................................
# [CV] END ................................ score: (test=7.777) total time=   0.2s
# [CV] START .....................................................................
# [CV] END ................................ score: (test=4.413) total time=   0.2s
# [CV] START .....................................................................
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [CV] END ................................ score: (test=4.650) total time=   0.1s
# ...

# %% [markdown]
# Линейна регрессия показала не плохой результат метрика Итоговой sMAPE, так средняя оценка качества модели: 8.973075463316194

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Не совсем понял, почему среднее значение модели на кросвалидации хуже, чем отдельно посчитаное full_smape? Я что-то не правильно делаю? На Деревьях и Случайном лесе аналогично.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# В целом это ожидаемо: `full_smape` ты считаешь на предсказаниях, которые сделал на тренировочной выборке, а оценку модели на тренировочной выборке делать не нужно, потому что такая оценка модель как таковую не оценивает - просто проверяет, как модель запомнила правильные ответы. Кросс-валидация же всегда откладывает на тестирование один фолд, который не участвовал в обучении, поэтому оценка кросс-валидацией более надёжна.
#
# Соответственно, `full_smape` на `train`, как в принципе и `fit-predict` делать не нужно - хватит кросс-валидации и метрики с этой проверки.
#
# Актуально тут и далее.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2 <a class="tocSkip"> </h2>
# Оставил только результаты Крос-валидации.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили линейную регрессию на кросс-валидации - отлично!
#
# При работе с `cross_val_score`, а также с `GridSearchCV` или `RandomizedSearchCV` есть несколько полезных действий, которые сделают нашу жизнь проще и лучше:)
#
# 1. Можно настроить параметр `n_jobs=-1`, чтобы для вычислений использовались все доступные ядра - это ускорит процесс.
# 2. Можно настроить параметр `verbose=10`, чтобы инструмент взаимодействовал с логом и выдавал сообщения о прогрессе обучения - так мы будем понимать, что процесс идёт, а не что, например, у нас упало ядро, и процесс завис.
# 3. Для кросс-валидации (параметр `cv`) вполне можно использовать и 3 фолда: мы немного потеряем в качестве, но процесс будет происходить гораздо быстрее. Для учебного проекта более чем достаточно:)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Довольно важным моментом является настройка параметра `scoring` - именно он отвечает за метрику, которая будет оценивать качество моделей в ходе кросс-валидации (в том числе при оптимизации гиперпараметров). Метрика нашего проекта - `sMAPE`, и в базовом наборе метрик `sklearn` она отсутствует - нам придётся сделать свой скорринг. Для этого можно использовать инструмент `make_scorer` (https://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html). Так как метрика `sMAPE` применяется для задач регрессии, то она тем лучше, чем ниже - это нужно учитывать при создании скорринга для кросс-валидации, так как по умолчанию инструменты кросс-валидации вроде `cross_val_score` и `GridSearchCV/RandomizedSearchCV` умеют только максимизировать метрику качества. Поэтому при создании скорринга с помощью `make_scorer` важно настроить параметр `greater_is_better=False`, чтобы оптимизируемая метрика минимизировалась, а не максимизировалась - таким образом задача максимизации будет решаться через задачу минимизации обратной функции. Также при настройке этого параметра получаемая метрика будет отрицательной: это особеность работы `make_scorer` с настроенным параметром `greater_is_better=False`. Поэтому при выводе метрики на экран её стоит сделать положительной: взять по модулю, домножить на `-1` или просто указать `-` при выводе на экран, вроде `print(-a)`.
# 2. Оценка модели на `test` - это преждевременное решение, так как оценка на тестовой выборке - это финальное тестирование для лучшей модели, которая была отобрана в ходе промежуточного тестирования. Эта концепция находит своё отражение в условиях эксплуатации модели в реальной среде: в промышленной эксплуатации не работает несколько моделей одновременно - в промышленную эксплуатацию запускают только одну модель, которая была выбрана из нескольких в ходе промежуточной оценки. Так же и здесь - тестовая выборка имитирует поток реальных данных, и с этим потоком должна работать только одна модель. На данном этапе мы должны выполнить промежуточную оценку на кросс-валидации, оптимизировать гиперпараметры моделей и выбрать одну лучшую - именно она будет оцениваться на `test`.
# 3. Сейчас средняя оценка модели - это оценка по коэффициенту `R2` - нужно будет скорректировать выводы после исправления п.1.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Обучим модель DecisionTreeRegressor

# %%
# посмотрим как работает модель DecisionTreeRegressor с глубиной до 10
best_model = None
best_result_dtc = []
best_depth_dtc = []
for depth in tqdm(range(1, 11)):
    # Модель расчета метрики на этапе флотации
    model_rougher = DecisionTreeRegressor(random_state=rand, max_depth=depth)
    
    scores_1 = cross_val_score(model_rougher, features_rougher, target_rougher, cv=5, n_jobs=-1, verbose=10, scoring=smape)
    final_score_1 = pd.Series(scores_1).mean()
    
    # Модель расчета метрики на следующих этапах    
    model_final = DecisionTreeRegressor(random_state=rand, max_depth=depth)
     
    scores_2 = cross_val_score(model_final, features_final, target_final, cv=5, n_jobs=-1, verbose=10, scoring=smape)
    final_score_2 = pd.Series(scores_2).mean()
    
    final_score = (abs(final_score_1)*0.25 + abs(final_score_2)*0.75)
    print(" Full_smape при кросвалидации:", final_score)
   

print("Средняя оценка качества модели:", final_score)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s][Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [CV] START .....................................................................
# [CV] END ............................... score: (test=11.718) total time=   0.0s
# [CV] START .....................................................................
# [CV] END ................................ score: (test=7.388) total time=   0.0s
# ...

# %% [markdown]
# <p>Fullsmape при кросвалидации: 13.383794496750317

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Для дерева решений оптимизировали гиперпараметры и оценили модель на кросс-валидации - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Тут аналогичные замечания. Также не стоит выводить на экран весь лог оптимизации - достаточно вывести лучшую метрику и лучшие гиперпараметры.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Обучим модель Случайного леса

# %%
# параметры для GridSearchCV
parametrs = { 'n_estimators': range (10, 91, 10),
              'max_depth': range (1,5, 2) } #min_samples_leaf': range (1,8), 'min_samples_split': range (2,10,2)

# %%
# Поиск лучших гипер-параметров на этапе флотации
rfr = RandomForestRegressor()
grid = GridSearchCV(rfr, parametrs, cv=5, n_jobs=-1, verbose=10, scoring=smape)
grid.fit(features_rougher, target_rougher)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 1/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 2/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 2/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 3/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 3/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 4/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 4/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 5/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 5/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 1/5; 2/18] START max_depth=1, n_estimators=20...............................
# ...

# %%
grid.best_params_
# Out:
# {'max_depth': 1, 'n_estimators': 30}

# %%
print("Лучший результат итогового sMAPE на кросвалидации", abs(grid.best_score_))
# Out:
# Лучший результат итогового sMAPE на кросвалидации 7.644295523073183

# %%
# Поиск лучших гипер-параметров на следующих этапах
rfr = RandomForestRegressor()
grid_final = GridSearchCV(rfr, parametrs, cv=5, n_jobs=-1, verbose=10, scoring=smape)
grid_final.fit(features_final, target_final)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 1/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.3s
# [CV 2/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 2/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 3/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 3/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 4/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 4/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.2s
# [CV 5/5; 1/18] START max_depth=1, n_estimators=10...............................
# [CV 5/5; 1/18] END .............max_depth=1, n_estimators=10; total time=   0.3s
# [CV 1/5; 2/18] START max_depth=1, n_estimators=20...............................
# ...

# %%
print("Лучший результат итогового sMAPE на кросвалидации", abs(grid_final.best_score_))
# Out:
# Лучший результат итогового sMAPE на кросвалидации 10.557985637617625

# %%
grid_final.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 20}

# %%
# Предсказания
predictions_rougher = grid.best_estimator_.predict(features_rougher)
predictions_final = grid_final.best_estimator_.predict(features_final)
# Результат
result  = full_smape(target_rougher, predictions_rougher, target_final, predictions_final)
print("Результат итогового sMAPE на кросвалидации, обучающая выборка", result)
# Out:
# Результат итогового sMAPE на кросвалидации, обучающая выборка 7.786225188940678

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# После использования `GridSearchCV` дополнительно кросс-валидацию делать не нужно, так как она уже была проведена в ходе оптимизации гиперпараметров - отсюда и постфикс `CV` на конце инструмента.
#
# Метрика с кросс-валидации находится в атрибуте `best_score_` - это и будет твоей метрикой на кросс-валидации. Тут тоже нужно будет поменять знак по аналогии с `cross_val_score`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Для случайного леса оптимизировали гиперпараметры и оценили модель на кросс-валидации - отлично!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Для гиперапараметра `n_estimators` оценивается очень короткая последовательность: по-настоящему этот алгоритм раскрывается при большом количестве деревьев. При поиске оптимального значения стоит исследовать более широкую последовательность с большим шагом - так шансы найти оптимальное количество деревьев выше, чем исследование короткой последовательности с маленьким шагом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Проверка на тестовой выборке

# %%
# Работа модели Случайного леса - GridSearchCV на тесте 

# Предсказания
predictions_rougher = grid.best_estimator_.predict(features_test_rougher)
predictions_final = grid_final.best_estimator_.predict(features_test_final)
# Результат
result  = full_smape(target_test_rougher, predictions_rougher, target_test_final, predictions_final)
print("Результат итогового sMAPE на кросвалидации, тестовая выборка", result)
# Out:
# Результат итогового sMAPE на кросвалидации, тестовая выборка 8.991719106282826

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Это тестирование лишнее:
# - во-первых, на `test` оценивается только одна лучшая модель - в нашем случае это случайный лес;
# - во-вторых, само тестирование модели организовано неверо: кросс-валидация предполагает деление выборки на фолды, на которых происходит и обучение, и тестирование - в итоге модель и обучается, и тестируется на тестовой выборке, что нарушает концепцию итогового тестирования. Тестирование модели предполагает обучение на `train`, создание предсказаний для `test` и оценку их точности.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Удалил лишние модели. Модели обученные методом крос-валидации лучше справляются с тестовой выборкой.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Далее должен быть вывод о том, какая модель оказалась лучшей по итогу оптимизации гиперпараметров и кросс-валидации, и эту модель оценить на `test`.
#
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Проверим качество работы модели

dummy_regr_1 = DummyRegressor(strategy="mean").fit(features_rougher, target_rougher)
predictions_rougher = dummy_regr_1.predict(features_test_rougher)
        
dummy_regr_2 = DummyRegressor(strategy="mean").fit(features_final, target_final)
predictions_final = dummy_regr_2.predict(features_test_final)
        
result  = full_smape(target_test_rougher, predictions_rougher, target_test_final, predictions_final)
print("SMAPE на модели DummyRegressor", result)
# Out:
# SMAPE на модели DummyRegressor 9.822322668938169

# %% [markdown]
# ### Выводы по результатам метрик моделей
# <p> На обучающей выборке:
# <p> Линейная регресия : Средняя оценка качества модели при кросс-валидации: 8.973075463316194
# <p> Обычная модель Линейна регрессия показала не плохой результат метрика sMAPE = 7.64941204072373
# <p> Дерево решений:
# <p>Средняя оценка качества модели Fullsmape при кросвалидации: 13.383794496750317
# <p>Лучшая SMAPE обычной модели 4.98322652540435
# <p>Модель Случайного леса:
# <p>Лучшая SMAPE обычной модели 7.099579445633997 , эстиматор 121 , глубина 4
# <p>Fullsmape при кросвалидации: 9.323560903248266, эстиматор 80 , глубина 1
#
# <p>На тестовой выборке:
# <p>На кросс валидации и на обычной модели показала луший результат.
# <p>SMAPE на обычной модели: 9.541818718866926
# <b><p>Fullsmape при кросвалидации: 9.239913028656593</b>
# <p>SMAPE на модели DummyRegressor 9.822322668938169
# <p>Модель Случайного леса при кросвалидации показала себя немного лучше чем константная модель.

# %% [markdown]
# ### Итоговый вывод
# <p>Судя по имеющимся данным каждый час происходит замер либо опрос датчиков и сбор показателей. Учитывая, что у многих производственных линий есть показатель норма выхода подукта в час. Скорее всего данные собираются в течении часа, а потом записываются (последовательный процесс). Возможен и другой вариант происходит паралельный-одновременный опрос датчиков каждый час, что не совсем логично (не посчитаешь эффективность).</p>
# <p>Линия обогащения судя по признаку дата работает круглые сутки, в несколько смен (трудовое законодательство). Изменения в показателях в зависимости от времени не заметил.   </p>
# <p>Далее по корреляции.</p>
# <p>Из данного датафрейма видно, что на этапе флотации происходит расчет количества реагентов, на основе параметров исходного сырья, далее подача сырья в флотационную установку. В данной установке происходит дважды добавление реагентов и многоступенчатое изменение объема воздуха и уровня жидкости. В итоге на выходе появляются концентраты ag, pb, sol, au и такие же аналогичные хвосты.</p>
#
# <p>Из тепловой карты корреляции видна слабая линейна взаимозависимость между параметрами скорости подачи сырья и добавлением концентратов, а также слабые линенейные зависимости на входе в содержании металлов в сырье и на выходы концентратов металлов между собой.</p>
#
# <p>Также видна средняя обратная зависимость между параметром rougher.calculation.au_pb_ratio и параметром сырья содержащего свинец. И есть линейные зависимости выше средней между параметрами входной продукции серебра и свинца, золота и свинца.</p>
#
# <p>И более чем логично, показатель rougher.output.recovery имеет выше средней корреляцию (линейную зависимость) с выходом параметров концентрата металлов.</p>
#
# <p>Также видно, что между параметрами уровня воды и жидкости присутствует высокая линейная зависимость.</p>
#
# <p>Кроме того, присутствует масса иных слабых зависимостей линейных и обратных между параметрами, которые решил не описывать.</p>
# <p>В расчетных характеристиках сырья, видны выбросы, очень похожие на аономальные значения (особенно в Feed_sol). Все распределения имеют минимум по два горба (моды). В этих признаках была перекрестная корреляция. Возможно содержание одного влияет на содержание другого, либо данные моды также могут отражать содержание металлов в руде. Руда из разных мест имеет разные концентрации. Также можно отметить, что содержание входного сырья Feed_sol многократно превышает значения других металлов. </p>
#
# Содержание металлов на входе:
# - серебро от 4 до 14
# - свинец от 1 до 7
# - золото от 4 до 13
# - sol от 20 до 45
#
# <p>Предположим, что данный признак это средний показатель скорости подачи для определенной партии по времени. Распределение смещено влево, присутствует одна ярко выраженная и несколько маленьких вершин.
# Много выбросов с минимальными показателями. Медианная скорость подачи около 500.</p>
# <p>Размер гранул сырья - распределение смещено в право, есть явные выбросы. Медианное значение 54,5. Половина значений в пределах 47-64.</p>
# <p>Хвосты детально исследовать не будем. Не совсем понятно это концентрация минерала в общем отвале или выходит 4 отвала. Вероятнее первый вариант. Видно, что в отвале: свинца минимум, золота побольше, а вот серебра и Sol большое количество.</p>
# <p>При сравнении концентрации минералов в исходном сырье и после флотации видно, что <b>концентрация Золота, Серебра и Свинца увеличилась. Cодержание SOL уменьшилось.</b> Скорее всего SOL - это соли. В отвал ушло много SOL. Также видны выбросы. Можно сказать, что распределение начало нормализовываться, но все еще есть смещение.<p>
# <b>Показателя эффективности обогащения чернового концентрата имеет распределение смещенное влево, медианное значение находится в районе 86. В целом показатель отражает качество руд подаваемых на обогащение. Отражает эффективность обогащения золота, судя по описанию проекта. Выбросы в районе 60-70.</b>
# <p>Также имеются технические признаки характеризующие количество реагентов и, объем воздуха и уровня жидкости на разных стадиях обогащения (детально не описываю).</p>
#
# <p>На диаграмме видны коррелирующиеся признаки например присутствует линейная зависимость реагента - сульфата и концетрата минералов на выходе. Другие реагенты, тоже имеют слабую линейную зависимость с качеством выхода концентрата. </p>
# <p>Распределение значений реагентов имеют смещение вправо, а также присутствуют выбросы. </p>
# Размер гранул сырья уменьшился после флотации.</p>
# <p>С подачей жидкости на этапе первичной очистки что-то не то, очень много выбросов. Есть случаи когда значения сильно отличается от моды. </p>
# <p>Признаки характеризующие подачу воздуха на этапе первичной очистки имеют аномальные выбросы.
# <p>После первичной очистки содержание серебра и sol в концентрате значительно уменьшилось. При этом содержание золота и свинца значительно увеличилось. <b>Содержание золота в среднем выросло на 70%.</b></p>
# <p>В отвалах выросло содержание серебра, свинца и незначительно золота. Содержание SOL уменьшилось. Значительное количество выбросов в распределениях также продолжает присутствовать.</p>
#
#
# <p>Здесь по корреляции признаков можно отметить следующее.</p>
# <p>Показатели воздуха и воды коррелируют между собой (прямая линейная зависимость), а также на 6 этапе влияет количество воздуха на отвалы SOL и имеют обратную зависимость на серебро и свинец. Подобный зависимости имеются и на других этапах но они имееют более слабую корреляцию. </p>
# <p>Также признаки характеризующие количество минералов в отвалах коррелируют между собой, зависимости разнонаправлены.</p>
# <p>На диаграмме видно поэтапное уменьшение количество воздуха, и рост на последнем этапе. </p>
# <p>На данном этапе присутствует значительная корреляция с признаками характеризующими содержание минералов в отвалах.</p>
# <p>Здесь также почти на всех этапах уровень воды в пределах медианы и только 4_b показывает плавающее значение.</p>
# <p>На этапе вторичной очистки в отвалах значительно <b> выросло содержание SOL и свинца, незначительно золота. Кроме того, незначительно упало содержание серебра.</b></p>
#
#
# <p>В концентрате сократилось содержание серебра, содержание свинца и SOL осталось примерно на том же уровне, но и самое важное, для чего собственно и был весь процесс, <b>содержание золота увеличилось до 45</b>.</p>
# <p>Также в распределении золото присутствует длинное предгорье (выбросы) слева, указывающие на то, что существует множество случаев когда золота в конечном продукте было низкое содержание. Причины могут быть разные, от низкого содержания минералов в руде, до плохого алгоритма обогащения.</p>
# <p>В отвалах по сравнению с предыдущими этапами уменьшилось содержание всех минералов.</p>
# <p>На вышеуказанных диаграммах видно, что эффективность обогащения на финальной стадии снизилась до 68 (медианное значение). При этом снизился показатель стандартного отклонения, что говорит о нормализации распределения.</p>
# <p>Размер гранул на обучающей и тестовой выборках визуально совпадают.</p>
# <p><b>Концентрация ценных металлов по результатам обогащения выросла.</p></b>
# <p> Модели:
# <p> На обучающей выборке:
# <p> Линейная регресия : Средняя оценка качества модели при кросс-валидации: 8.973075463316194
# <p> Дерево решений:
# <p>Средняя оценка качества модели Fullsmape при кросвалидации: 13.383794496750317
# <p>Модель Случайного леса:
# <p>Результат итогового sMAPE на кросвалидации, обучающая выборка 7.834842154506024
# <p>На тестовой выборке:
# <b>Результат модели Случайного леса (gridCV) итоговое sMAPE , тестовая выборка 8.930864765970519</b>
# <p>SMAPE на модели DummyRegressor 9.822322668938169
# <p>Модель Случайного леса при кросвалидации показала себя лучше чем константная модель.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный итоговый вывод!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Блок с моделями нужно будет скорректировать по итогу устранения замечаний.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *Постарался исправить все замечания. Основной вопрос, почему среднее качество модели при кроссвалидации иногда хуже чем при работе обычной модели. Особенно это видно на дереве решений? *
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Ещё актуально - количество метрик в выводе должно уменьшиться.
#
# На твой вопрос, кажется, ответил по ходу проекта, если правильного его понял. Если нет - дай мне знать, я переформулирую:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2 <a class="tocSkip"> </h2>
#
# *Спасибо стало намного понятнее. Метрики лишние убрал. *
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Николай, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров, ыполнена промежуточная оценка моделей на кросс-валидации - молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.2.
#
# Николай, продолжаем работу над проектом - актуальные замечания отмечены комментариями с меткой `v.2`.
#
# Жду тебя снова:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту v.3.
#
# Николай, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
